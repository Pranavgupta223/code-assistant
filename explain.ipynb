# %% [markdown]
# | File            | Job                    |
# | --------------- | ---------------------- |
# | `main.py`       | main execution/testing |
# | `ingest.py`     | read files + chunk     |
# | `retriever.py`  | search logic           |
# | `utils.py`      | helper functions       |
# | `data/`         | uploaded projects      |
# | `vector_store/` | saved embeddings/index |
